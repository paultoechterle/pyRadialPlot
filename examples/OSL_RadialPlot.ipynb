# %%
from matplotlib import rcParams
from pyRadialPlot import general_radial

rcParams["figure.dpi"] = 300

# %%
ax = general_radial(file="ressources/OSLdata.csv", transform="logarithmic")

# %%
ax = general_radial(file="ressources/OSLdata.csv", transform="linear")

# %%
ax = general_radial(file="ressources/OSLdata.csv", transform="sqrt")
